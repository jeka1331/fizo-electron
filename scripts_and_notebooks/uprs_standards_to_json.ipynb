# %%
import pandas as pd
import numpy as np

# %%
allUprsStandards = pd.DataFrame(columns=['uprazhnenieId','categoryId', 'value', 'result'])

# %%
def convert_fraction_to_seconds(fraction):
    
    if isinstance(fraction, float):
        minutes = int(fraction)
        seconds_decimal = (fraction - minutes) * 100  # Умножаем на 100, так как 1.5 соответствует 1 минуте и 50 секундам
        seconds = round(seconds_decimal)
        total_seconds = minutes * 60 + seconds
        return total_seconds
    elif isinstance(fraction, int):
        minutes = int(fraction)
        total_seconds = minutes * 60
        return total_seconds
    elif isinstance(fraction, str):
        try:
            minutes, seconds_fraction = map(int, fraction.split(','))
            seconds = seconds_fraction % 100
            minutes += seconds_fraction // 100
            total_seconds = minutes * 60 + seconds
            return total_seconds
        except ValueError:
            print("Некорректный формат строки. Используйте формат 'минуты, секунды'")
            return None
    else:
        print("Неподдерживаемый тип аргумента. Используйте либо float, либо str.")
        return None


def convert_fraction_h_to_seconds(fraction):
    try:
        hours, minutes, seconds = map(int, fraction.split('.'))
        total_seconds = hours * 3600 + minutes * 60 + seconds
        return total_seconds
    except ValueError:
        print("Некорректный формат строки. Используйте формат 'часы.минуты.секунды'")
        return None


def cat_name_to_index_mans(name: str):
    if name == '1-я возрастная группа, курсанты 3-го курса и старше':
        return 1
    if name == '1-я возрастная группа':
        return 1
    if name == '1-я возр группа, курсанты3-го курса и старше':
        return 1
    if name == '1-явозрастная группа, курсанты 3-го курса и старше':
        return 1
    if name == '2- я возрастная группа, курсанты и кадеты 2-го курса':
        return 2
    if name == '2- я возрастная группа':
        return 2
    if name == '2- я возр группа, курсанты и кадеты 2-го курса':
        return 2
    if name == '2-явозрастная группа, курсанты и кадеты 2-го курса':
        return 2
    if name == '2-я возрастная группа, курсанты и кадеты 2-го курса':
        return 2
    if name == '3-я возрастная группа':
        return 3
    if name == '3- я возр группа':
        return 3
    if name == '3-явозрастная группа':
        return 3
    if name == '4-я возрастная группа':
        return 4
    if name == '4- я возр группа':
        return 4
    
    if name == '3- я возрастная группа':
        return 3
    if name == '4- я возрастная группа':
        return 4
    if name == '4- я возр группа':
        return 4
    if name == '5- я возрастная группа':
        return 5
    if name == '5- я возр группа':
        return 5
    if name == '6- я возрастная группа':
        return 6
    if name == '6- я возр группа':
        return 6
    if name == '7- я возрастная группа':
        return 7
    if name == '7- я возр группа':
        return 7
    if name == '8- я возрастная группа':
        return 8
    if name == '8- я возр группа':
        return 8
    if name == '8-я возрастная группа':
        return 8
    if name == 'Курсанты, кадеты и военнослужащие, проходящие воинскую службу по призыву до 6 месяцев службы':
        return 17
    if name == 'Курсанты, кадеты и военнослужащие, проходящие воинскую службу по призыву после 6 месяцев службы':
        return 18
    if name == 'Курсанты и военнослужащие, проходящие воинскую службу по призыву после 6 месяцев службы':
        return 18
    if name == 'Военнослужащие, проходящие воинскую службу по призыву после 6 месяцев службы':
        return 18
    if name == 'Юноши':
        return 19
    if name == 'Курсанты и кадеты после 6 месяцев службы':
        return 57
    if name == 'Курсанты и кадеты 2-го курса':
        return 58
    if name == 'Курсанты 3-го курса и старше':
        return 59
    
    return None


def cat_name_to_index_women(name: str):
    if name == '1- я возрастная группа':
        return 9
    if name == '2- я возрастная группа':
        return 10
    if name == '3- я возрастная группа':
        return 11
    if name == '4- я возрастная группа':
        return 12
    if name == '5- я возрастная группа':
        return 13
    if name == '6 я возрастная группа':
        return 14
    if name == '7- я возрастная группа':
        return 15
    if name == '1- я возр группа':
        return 9
    if name == '2- я возр группа':
        return 10
    if name == '3- я возр группа':
        return 11
    if name == '4- я возр группа':
        return 12
    if name == '5- я возр группа':
        return 13
    if name == '6 я возр группа':
        return 14
    if name == '7- я возр группа':
        return 15
    if name == 'Курсанты и кадеты до 6 месяцев службы':
        return 53
    if name == 'Курсанты и кадеты после 6 месяцев службы':
        return 54 
    if name == 'Курсанты и кадеты 2-го курса':
        return 55
    if name == 'Курсанты 3-го курса и старше':
        return 56
    if name == 'Девушки':
        return 52
    if name == 'Юноши':
        return 19
    return None
def cat_name_to_index_sfpis(name: str):
    if name == '1-я возрастная группа':
        return 20
    if name == '2- я возрастная группа':
        return 21
    if name == '2-я возрастная группа':
        return 21
    if name == '3-я возрастная группа':
        return 22
    if name == '3- я возрастная группа':
        return 22
    if name == '4- я возрастная группа':
        return 23
    if name == '5- я возрастная группа':
        return 24
    if name == '6- я возрастная группа':
        return 25
    if name == '7- я возрастная группа':
        return 26
    if name == '8- я возрастная группа':
        return 27
    
    
    if name == '1-возрастная группа':
        return 20
    if name == '2-возрастная группа':
        return 21
    if name == '3-возрастная группа':
        return 22
    if name == '4-возрастная группа':
        return 23
    if name == '5-возрастная группа':
        return 24
    if name == '6-возрастная группа':
        return 25
    if name == '7-возрастная группа':
        return 26
    if name == '8-возрастная группа':
        return 27

    return None
    
def cat_name_to_index_sfpis_15(name: str):
    if name == '1-я возрастная группа до 70 килограмм':
        return 28
    if name == '1-я возрастная группа свыше 70 килограмм':
        return 39
    if name == '2- я возрастная группа до 70 килограмм':
        return 29
    if name == '2- я возрастная группа свыше 70 килограмм':
        return 40
    if name == '3- я возрастная группа до 70 килограмм':
        return 30
    if name == '3- я возрастная группа свыше 70 килограмм':
        return 41
    if name == '4- я возрастная группа до 70 килограмм':
        return 31
    if name == '4- я возрастная группа свыше 70 килограмм':
        return 42
    if name == '5- я возрастная группа до 70 килограмм':
        return 32
    if name == '5- я возрастная группа свыше 70 килограмм':
        return 43
    if name == '6- я возрастная группа до 70 килограмм':
        return 46
    if name == '6- я возрастная группа свыше 70 килограмм':
        return 44
    if name == '7- я возрастная группа до 70 килограмм':
        return 47
    if name == '7- я возрастная группа свыше 70 килограмм':
        return 45

    return None

def cat_name_to_index_mans_15(name: str):
  
    if name == '1-я возрастная группа, курсанты 3-го курса и старше до 70 килограмм':
        return 33
    if name == '1-я возрастная группа, курсанты 3-го курса и старше свыше 70 килограмм':
        return 36
    if name == '2-я возрастная группа, курсанты и кадеты 2-го курса до70 килограмм':
        return 34
    if name == '2-я возрастная группа, курсанты и кадеты 2-го курса свыше 70 килограмм':
        return 37
    if name == '3-я возрастная группа группы до 70 килограмм':
        return 35
    if name == '3-я возрастная группа группы свыше 70 килограмм':
        return 38
    if name == 'Курсанты, кадеты и военнослужащие, проходящие воинскую службу по призыву до 6 месяцев службы до 70 кило грамм':
        return 48
    if name == 'Курсанты, кадеты и военнослужащие, проходящие воинскую службу по призыву до 6 месяцев службы свыше 70 килограмм':
        return 50
    if name == 'Курсанты, кадеты и военнослужащие, проходящие воинскую службу по призыву после 6 месяцев службы до 70 килограмм':
        return 49
    if name == 'Курсанты, кадеты и военнослужащие, проходящие воинскую службу по призыву после 6 месяцев службы свыше 70 килограмм':
        return 51


    return None

# %%
data = pd.read_excel('../uprs/Упражнение № 16 Комплексное силовое упражнение.xls', engine="xlrd",usecols= 'B:AE', skiprows=[0], nrows=21).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 16 Комплексное силовое упражнение.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=21).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (5, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 16 Комплексное силовое упражнение.xls', engine="xlrd",usecols= 'E:AE', skiprows=35).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 16 Комплексное силовое упражнение.xls', engine="xlrd",usecols= 'A', skiprows=35).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (5, category_temp, _r, datarl[index])
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 3 Подтягивание на перекладине.xls', engine="xlrd",usecols= 'B:U', skiprows=[0], nrows=9).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 3 Подтягивание на перекладине.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (1, category_temp, _r, datarl[index])
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 3 Подтягивание на перекладине.xls', engine="xlrd",usecols= 'B:U', skiprows=12, nrows=9).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 3 Подтягивание на перекладине.xls', engine="xlrd",usecols= 'A', skiprows=12, nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (1, category_temp, _r, datarl[index])
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 4 Поднимание ног к перекладине.xls', engine="xlrd",usecols= 'B:O', skiprows=[0], nrows=9).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 4 Поднимание ног к перекладине.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (2, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 4 Поднимание ног к перекладине.xls', engine="xlrd",usecols= 'B:O', skiprows=12, nrows=9).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 4 Поднимание ног к перекладине.xls', engine="xlrd",usecols= 'A', skiprows=12, nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (2, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 5 Подъем переворотом на перекладине.xls', engine="xlrd",usecols= 'B:L', skiprows=[0], nrows=9).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 5 Подъем переворотом на перекладине.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (3, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 5 Подъем переворотом на перекладине.xls', engine="xlrd",usecols= 'B:L', skiprows=12, nrows=9).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 5 Подъем переворотом на перекладине.xls', engine="xlrd",usecols= 'A', skiprows=12, nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (3, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 6 Подъем силой на перекладине.xls', engine="xlrd",usecols= 'B:J', skiprows=[0], nrows=9).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 6 Подъем силой на перекладине.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (4, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 6 Подъем силой на перекладине.xls', engine="xlrd",usecols= 'B:J', skiprows=12, nrows=9).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 6 Подъем силой на перекладине.xls', engine="xlrd",usecols= 'A', skiprows=12, nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (4, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 8 Сгибание и разгибание рук в упоре на брусьях.xls', engine="xlrd",usecols= 'B:U', skiprows=[0], nrows=9).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 8 Сгибание и разгибание рук в упоре на брусьях.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (6, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 8 Сгибание и разгибание рук в упоре на брусьях.xls', engine="xlrd",usecols= 'B:U', skiprows=12, nrows=9).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 8 Сгибание и разгибание рук в упоре на брусьях.xls', engine="xlrd",usecols= 'A', skiprows=12, nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (6, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 7 Комбинированное силовое упражнение на перекладине.xls', engine="xlrd",usecols= 'C:H', skiprows=[0], nrows=3).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 7 Комбинированное силовое упражнение на перекладине.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=3).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (5, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 7 Комбинированное силовое упражнение на перекладине.xls', engine="xlrd",usecols= 'B:H', skiprows=6, nrows=3).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 7 Комбинированное силовое упражнение на перекладине.xls', engine="xlrd",usecols= 'A', skiprows=6, nrows=3).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (5, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 9 Угол в упоре на брусьях.xls', engine="xlrd",usecols= 'B:L', skiprows=[0], nrows=9).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 9 Угол в упоре на брусьях.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (7, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 9 Угол в упоре на брусьях.xls', engine="xlrd",usecols= 'B:L', skiprows=12, nrows=9).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 9 Угол в упоре на брусьях.xls', engine="xlrd",usecols= 'A', skiprows=12, nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (7, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 15 Поднимание гири 24 килограмм (рывок).xls', engine="xlrd",skiprows=13, nrows=9, header=[0,1]).dropna(axis=1)
data.drop(columns=data.columns[0], axis=1, inplace=True)
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 15 Поднимание гири 24 килограмм (рывок).xls', engine="xlrd",usecols= 'A', skiprows=14, nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        c_name = ' '.join(_i)
        category_temp = cat_name_to_index_sfpis_15(c_name) if cat_name_to_index_sfpis_15(c_name) is not None else c_name
        if (_r) is not None:
            res = (8, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 15 Поднимание гири 24 килограмм (рывок).xls', engine="xlrd",skiprows=1, nrows=9, header=[0,1]).dropna(axis=1)
data.drop(columns=data.columns[0], axis=1, inplace=True)
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 15 Поднимание гири 24 килограмм (рывок).xls', engine="xlrd",usecols= 'A', skiprows=2, nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        c_name = ' '.join(_i)
        category_temp = cat_name_to_index_mans_15(c_name) if cat_name_to_index_mans_15(c_name) is not None else c_name
        if (_r) is not None:
            res = (8, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 15 Поднимание гири 24 килограмм (рывок).2.xls', engine="xlrd",skiprows=1, nrows=9, header=[0,1]).dropna(axis=1)
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 15 Поднимание гири 24 килограмм (рывок).xls', engine="xlrd",usecols= 'A', skiprows=14, nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        c_name = ' '.join(_i)
        category_temp = cat_name_to_index_sfpis_15(c_name) if cat_name_to_index_sfpis_15(c_name) is not None else c_name
        if (_r) is not None:
            res = (8, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 16 Комплексное силовое упражнение.xls', engine="xlrd",usecols= 'B:AE', skiprows=[0], nrows=21).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 16 Комплексное силовое упражнение.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=21).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (9, category_temp, _r, datarl[index])
            
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 16 Комплексное силовое упражнение.xls', engine="xlrd",usecols= 'E:AE', skiprows=35).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 16 Комплексное силовое упражнение.xls', engine="xlrd",usecols= 'A', skiprows=35).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (11, category_temp, _r, datarl[index])
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 16 Комплексное силовое упражнение.xls', engine="xlrd",usecols= 'C:AE', skiprows=24, nrows=9).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 16 Комплексное силовое упражнение.xls', engine="xlrd",usecols= 'A', skiprows=24, nrows=9).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_women(_i) if cat_name_to_index_women(_i) is not None else _i
        if (_r) is not None:
            res = (10, category_temp, _r, datarl[index])
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 19 Упражнение на стационарном колесе.xls', engine="xlrd",usecols= 'B:K', skiprows=[0], nrows=21).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 19 Упражнение на стационарном колесе.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=21).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (12, category_temp, float(str(_r).replace(',', '.')), datarl[index])
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 19 Упражнение на стационарном колесе.xls', engine="xlrd",usecols= 'C:K', skiprows=24).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 19 Упражнение на стационарном колесе.xls', engine="xlrd",usecols= 'A', skiprows=24).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (12, category_temp, float(str(_r).replace(',', '.')), datarl[index])
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 21 Упражнение на лопинге.xls', engine="xlrd",usecols= 'B:J', skiprows=[0], nrows=21).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 21 Упражнение на лопинге.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=21).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (13, category_temp, float(str(_r).replace(',', '.')), datarl[index])
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 21 Упражнение на лопинге.xls', engine="xlrd",usecols= 'C:J', skiprows=24).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 21 Упражнение на лопинге.xls', engine="xlrd",usecols= 'A', skiprows=24).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (13, category_temp, float(str(_r).replace(',', '.')), datarl[index])
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 27 Общее контрольное упражнение на единой полосе препятствий.xls', engine="xlrd",usecols= 'B:K', skiprows=[0], nrows=21).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 27 Общее контрольное упражнение на единой полосе препятствий.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=21).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (14, category_temp, convert_fraction_to_seconds(_r), datarl[index])
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 27 Общее контрольное упражнение на единой полосе препятствий.xls', engine="xlrd",usecols= 'C:K', skiprows=24).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 27 Общее контрольное упражнение на единой полосе препятствий.xls', engine="xlrd",usecols= 'A', skiprows=24).dropna(axis=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            
            res = (14, category_temp, convert_fraction_to_seconds(_r), datarl[index])
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 28 Специальное контрольное упражнение для военных учебных заведений.xls', engine="xlrd",usecols= 'D:I', skiprows=[0], nrows=21).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 28 Специальное контрольное упражнение для военных учебных заведений.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=21).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN

datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (15, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 28 Специальное контрольное упражнение для военных учебных заведений.xls', engine="xlrd",usecols= 'B:I', skiprows=24).dropna(axis=1, thresh=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 28 Специальное контрольное упражнение для военных учебных заведений.xls', engine="xlrd",usecols= 'A', skiprows=24).dropna(axis=1, thresh=1) 
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            
            res = (15, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 29 Специальное контрольное упражнение для личного состава Десантно-штурмовых войск.xls', engine="xlrd",usecols= 'B:I', skiprows=[0], nrows=21).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 29 Специальное контрольное упражнение для личного состава Десантно-штурмовых войск.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=21).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN

datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (16, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 29 Специальное контрольное упражнение для личного состава Десантно-штурмовых войск.xls', engine="xlrd",usecols= 'C:I', skiprows=24).dropna(axis=1, thresh=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 29 Специальное контрольное упражнение для личного состава Десантно-штурмовых войск.xls', engine="xlrd",usecols= 'A', skiprows=24).dropna(axis=1, thresh=1) 
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            
            res = (16, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 30 Преодоление единой полосы препятствий в составе подразделения (для военных учебных заведений).xls', engine="xlrd",usecols= 'B:D', skiprows=[0]).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 30 Преодоление единой полосы препятствий в составе подразделения (для военных учебных заведений).xls', engine="xlrd",usecols= 'A', skiprows=[0]).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (17, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 31 Бег с преодолением полосы препятствий в составе подразделения (для военных учебных заведений).xls', engine="xlrd",usecols= 'B:G', skiprows=[0,2]).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data = data[['Курсанты 3-го курса и старше', 'Курсанты и кадеты 2-го курса', 'Курсанты и кадеты после 6 месяцев службы']]
data

datar = pd.read_excel('../uprs/Упражнение № 31 Бег с преодолением полосы препятствий в составе подразделения (для военных учебных заведений).xls', engine="xlrd",usecols= 'A', skiprows=[0,2]).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN

datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (18, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 31 Бег с преодолением полосы препятствий в составе подразделения (для военных учебных заведений).xls', engine="xlrd",usecols= 'B:G', skiprows=[0,2]).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data = data[['Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6']]
data.columns = ['Курсанты 3-го курса и старше', 'Курсанты и кадеты 2-го курса', 'Курсанты и кадеты после 6 месяцев службы']
data

datar = pd.read_excel('../uprs/Упражнение № 31 Бег с преодолением полосы препятствий в составе подразделения (для военных учебных заведений).xls', engine="xlrd",usecols= 'A', skiprows=[0,2]).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN

datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (37, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 32 Специальное контрольное упражнение для личного состава подразделений, предназначенных для действий в горах.xls', engine="xlrd",usecols= 'C:I', skiprows=[0], nrows=21).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 32 Специальное контрольное упражнение для личного состава подразделений, предназначенных для действий в горах.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=21).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN

datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (19, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 32 Специальное контрольное упражнение для личного состава подразделений, предназначенных для действий в горах.xls', engine="xlrd",usecols= 'B:I', skiprows=24).dropna(axis=1, thresh=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 32 Специальное контрольное упражнение для личного состава подразделений, предназначенных для действий в горах.xls', engine="xlrd",usecols= 'A', skiprows=24).dropna(axis=1, thresh=1) 
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            
            res = (19, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 33 Специальное контрольное упражнение для личного состава надводных кораблей.xls', engine="xlrd",usecols= 'C:I', skiprows=[0], nrows=21).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 33 Специальное контрольное упражнение для личного состава надводных кораблей.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=21).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN

datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (20, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 33 Специальное контрольное упражнение для личного состава надводных кораблей.xls', engine="xlrd",usecols= 'B:I', skiprows=24).dropna(axis=1, thresh=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 33 Специальное контрольное упражнение для личного состава надводных кораблей.xls', engine="xlrd",usecols= 'A', skiprows=24).dropna(axis=1, thresh=1) 
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            
            res = (20, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 34 Бег на 100 метров.xls', engine="xlrd",usecols= 'B:H', skiprows=[0]).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 34 Бег на 100 метров.xls', engine="xlrd",usecols= 'A', skiprows=[0]).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN

datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (21, category_temp, float(str(_r).replace(',', '.')), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 34 Бег на 100 метров.2.xls', engine="xlrd",usecols= 'D:M', skiprows=14).dropna(axis=1, thresh=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 34 Бег на 100 метров.2.xls', engine="xlrd",usecols= 'A', skiprows=14).dropna(axis=1, thresh=1) 
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            
            res = (21, category_temp,  float(str(_r).replace(',', '.')), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 34 Бег на 100 метров.2.xls', engine="xlrd",usecols= 'A:M', skiprows=[0], nrows=11).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 34 Бег на 100 метров.2.xls', engine="xlrd",usecols= 'A', skiprows=14).dropna(axis=1, thresh=1) 
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_women(_i) if cat_name_to_index_women(_i) is not None else _i
        category_temp = cat_name_to_index_mans(category_temp) if cat_name_to_index_mans(category_temp) is not None else category_temp
        if (_r) is not None:
            res = (21, category_temp, float(str(_r).replace(',', '.')), datarl[index])
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 35 Челночный бег 10х10 метров.xls', engine="xlrd",usecols= 'B:H', skiprows=[0]).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 35 Челночный бег 10х10 метров.xls', engine="xlrd",usecols= 'A', skiprows=[0]).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (22, category_temp, float(str(_r).replace(',', '.')), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 35 Челночный бег 10х10 метров.2.xls', engine="xlrd",usecols= 'D:M', skiprows=24).dropna(axis=1, thresh=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 35 Челночный бег 10х10 метров.2.xls', engine="xlrd",usecols= 'A', skiprows=24).dropna(axis=1, thresh=1) 
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            
            res = (22, category_temp,  float(str(_r).replace(',', '.')), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 35 Челночный бег 10х10 метров.2.xls', engine="xlrd",usecols= 'A:M', skiprows=[0], nrows=11).dropna(axis=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 35 Челночный бег 10х10 метров.2.xls', engine="xlrd",usecols= 'A', skiprows=24).dropna(axis=1, thresh=1) 
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar
datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_women(_i) if cat_name_to_index_women(_i) is not None else _i
        category_temp = cat_name_to_index_mans(category_temp) if cat_name_to_index_mans(category_temp) is not None else category_temp
        if (_r) is not None:
            res = (22, category_temp, float(str(_r).replace(',', '.')), datarl[index])
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 36 Бег на 400 метров.xls', engine="xlrd",usecols= 'B:I', skiprows=[0], nrows=9).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 36 Бег на 400 метров.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=9).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (23, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 36 Бег на 400 метров.xls', engine="xlrd",usecols= 'D:I', skiprows=12).dropna(axis=1, thresh=1) 
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 36 Бег на 400 метров.xls', engine="xlrd",usecols= 'A', skiprows=12).dropna(axis=1, thresh=1) 
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])

for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            
            res = (23, category_temp,  convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 37 Бег на 1000 метров.xls', engine="xlrd",usecols= 'B:K', skiprows=[0]).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 37 Бег на 1000 метров.xls', engine="xlrd",usecols= 'A', skiprows=[0]).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (24, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 37 Бег на 1000 метров.2.xls', engine="xlrd",usecols= 'A:T', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 37 Бег на 1000 метров.2.xls', engine="xlrd",usecols= 'A', skiprows=44).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_women(_i) if cat_name_to_index_women(_i) is not None else _i
        if (_r) is not None:
            res = (24, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 37 Бег на 1000 метров.2.xls', engine="xlrd",usecols= 'B:T', skiprows=44).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 37 Бег на 1000 метров.2.xls', engine="xlrd",usecols= 'A', skiprows=44).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (24, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 38 Бег на 3000 метров.xls', engine="xlrd",usecols= 'B:U', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 38 Бег на 3000 метров.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (25, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 38 Бег на 3000 метров.xls', engine="xlrd",usecols= 'C:U', skiprows=44).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 38 Бег на 3000 метров.xls', engine="xlrd",usecols= 'A', skiprows=44).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (25, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 39 Бег на 5000 метров.xls', engine="xlrd",usecols= 'C:O', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 39 Бег на 5000 метров.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (26, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 39 Бег на 5000 метров.xls', engine="xlrd",usecols= 'B:O', skiprows=44).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 39 Бег на 5000 метров.xls', engine="xlrd",usecols= 'A', skiprows=44).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (26, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 40 Метание гранаты Ф – 1 (600 грамм) на дальность.xls', engine="xlrd",usecols= 'B:H,M', skiprows=[0], nrows=11).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 40 Метание гранаты Ф – 1 (600 грамм) на дальность.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=11).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (27, category_temp, _r, int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 40 Метание гранаты Ф – 1 (600 грамм) на дальность.xls', engine="xlrd",usecols= 'I:L', skiprows=[0], nrows=11).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data[['1- я возрастная группа']] = data[['1-я и 2-я возрастные группы']] 
data[['2- я возрастная группа']] = data[['1-я и 2-я возрастные группы']] 
data.drop(columns=['1-я и 2-я возрастные группы'],inplace=True)
data

datar = pd.read_excel('../uprs/Упражнение № 40 Метание гранаты Ф – 1 (600 грамм) на дальность.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=11).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_women(_i) if cat_name_to_index_women(_i) is not None else _i
        if (_r) is not None:
            res = (27, category_temp, _r, int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 40 Метание гранаты Ф – 1 (600 грамм) на дальность.xls', engine="xlrd",usecols= 'F:M', skiprows=14).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 40 Метание гранаты Ф – 1 (600 грамм) на дальность.xls', engine="xlrd",usecols= 'A', skiprows=14).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (27, category_temp, _r, int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 42 Марш-бросок на 5 километров.xls', engine="xlrd",usecols= 'B:J', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 42 Марш-бросок на 5 километров.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (28, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 42 Марш-бросок на 5 километров.xls', engine="xlrd",usecols= 'B:J', skiprows=44).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 42 Марш-бросок на 5 километров.xls', engine="xlrd",usecols= 'A', skiprows=44).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (28, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 43 Марш-бросок на 10 километров.xls', engine="xlrd",usecols= 'B:J', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 43 Марш-бросок на 10 километров.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (29, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 43 Марш-бросок на 10 километров.xls', engine="xlrd",usecols= 'B:J', skiprows=44).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 43 Марш-бросок на 10 километров.xls', engine="xlrd",usecols= 'A', skiprows=44).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (29, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 44 Лыжная гонка на 5 километров.xls', engine="xlrd",usecols= 'B:K', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 44 Лыжная гонка на 5 километров.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (30, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 44 Лыжная гонка на 5 километров.2.xls', engine="xlrd",usecols= 'A:S', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 44 Лыжная гонка на 5 километров.2.xls', engine="xlrd",usecols= 'A', skiprows=44).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_women(_i) if cat_name_to_index_women(_i) is not None else _i
        if (_r) is not None:
            res = (30, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 44 Лыжная гонка на 5 километров.2.xls', engine="xlrd",usecols= 'B:S', skiprows=44).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 44 Лыжная гонка на 5 километров.2.xls', engine="xlrd",usecols= 'A', skiprows=44).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (30, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 45 Лыжная гонка на 10 километров.xls', engine="xlrd",usecols= 'D:K', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 45 Лыжная гонка на 10 километров.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (31, category_temp, convert_fraction_h_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 45 Лыжная гонка на 10 километров.xls', engine="xlrd",usecols= 'B:K', skiprows=44).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 45 Лыжная гонка на 10 километров.xls', engine="xlrd",usecols= 'A', skiprows=44).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (31, category_temp, convert_fraction_h_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 46 Марш на лыжах 5 километров в составе подразделения.xls', engine="xlrd",usecols= 'B:E', skiprows=[0]).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 46 Марш на лыжах 5 километров в составе подразделения.xls', engine="xlrd",usecols= 'A', skiprows=[0]).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (32, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 47 Марш на лыжах 10 километров в составе подразделения.xls', engine="xlrd",usecols= 'B:E', skiprows=[0]).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 47 Марш на лыжах 10 километров в составе подразделения.xls', engine="xlrd",usecols= 'A', skiprows=[0]).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (33, category_temp, convert_fraction_h_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 48 Плавание на 100 метров в спортивной форме.xls', engine="xlrd",usecols= 'B:K', skiprows=[0]).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 48 Плавание на 100 метров в спортивной форме.xls', engine="xlrd",usecols= 'A', skiprows=[0]).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (34, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 48 Плавание на 100 метров в спортивной форме.2.xls', engine="xlrd",usecols= 'A:U', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 48 Плавание на 100 метров в спортивной форме.xls', engine="xlrd",usecols= 'A', skiprows=[0]).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_women(_i) if cat_name_to_index_women(_i) is not None else _i
        if (_r) is not None:
            res = (34, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 48 Плавание на 100 метров в спортивной форме.2.xls', engine="xlrd",usecols= 'B:U', skiprows=44).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 48 Плавание на 100 метров в спортивной форме.xls', engine="xlrd",usecols= 'A', skiprows=[0]).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (34, category_temp, convert_fraction_to_seconds(_r), int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 49 Плавание в обмундировании с оружием.xls', engine="xlrd",usecols= 'B:R', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 49 Плавание в обмундировании с оружием.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=41).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (35, category_temp, _r, int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 49 Плавание в обмундировании с оружием.xls', engine="xlrd",usecols= 'B:M', skiprows=44).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 49 Плавание в обмундировании с оружием.xls', engine="xlrd",usecols= 'A', skiprows=44).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (35, category_temp, _r, int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 50 Ныряние в длину.xls', engine="xlrd",usecols= 'B:M', skiprows=[0], nrows=11).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 50 Ныряние в длину.xls', engine="xlrd",usecols= 'A', skiprows=[0], nrows=11).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_mans(_i) if cat_name_to_index_mans(_i) is not None else _i
        if (_r) is not None:
            res = (36, category_temp, _r, int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
data = pd.read_excel('../uprs/Упражнение № 50 Ныряние в длину.xls', engine="xlrd",usecols= 'C:J', skiprows=14).dropna(axis=1, thresh=1) 
data.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
data.replace('-', None, inplace=True)  # Заменяем "-" на NaN
data

datar = pd.read_excel('../uprs/Упражнение № 50 Ныряние в длину.xls', engine="xlrd",usecols= 'A', skiprows=14).dropna(axis=1, thresh=1) 
datar.replace('-', None, inplace=True)  # Заменяем "-" на NaN
datar.replace(np.nan, None, inplace=True)  # Заменяем "-" на NaN
datar

datarl = {}
for index, row in datar.iterrows():
    datarl[index] = row.to_list()[0]
    # print(index, row.to_list()[0])
 
for index, row in data.iterrows():
    # print({index: row.to_dict()})
    for _i , _r in row.to_dict().items():
        category_temp = cat_name_to_index_sfpis(_i) if cat_name_to_index_sfpis(_i) is not None else _i
        if (_r) is not None:
            res = (36, category_temp, _r, int(datarl[index]))
            print(res)
            allUprsStandards.loc[len(allUprsStandards)] = res

# %%
allUprsStandards.to_json(orient='records')
allUprsStandards[['uprazhnenieId']] = allUprsStandards[['uprazhnenieId']].astype(int)
allUprsStandards[['categoryId']] = allUprsStandards[['categoryId']].astype(int)
allUprsStandards[['result']] = allUprsStandards[['result']].astype(int)
print(allUprsStandards.dtypes)

allUprsStandards

# %%
allUprsStandards.to_json(orient='records')
